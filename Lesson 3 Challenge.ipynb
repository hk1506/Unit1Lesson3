# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

#reading file
welcome = pd.read_csv('welcome.csv', encoding = "ISO-8859-1")
# %matplotlib inline

# %%
welcome.describe()
# Out:
#        PMID/PMCID Publisher Journal title  \
# count        1928      2127          2126
# unique       1880       299           984
# top             -  Elsevier      PLoS One
# freq            7       387            92
#
#                                             Article title  \
# count                                                2127
# unique                                               2126
# top     Exclusive breastfeeding, diarrhoel morbidity a...
# freq                                                    2
#
#        COST (£) charged to Wellcome (inc VAT when charged)
# count                                                2127
# unique                                               1402
# top                                              £2040.00
# freq                                                   94

# %%
welcome
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# ...

# %%
# Top 5 journals: groupby journal title and count how many times it was listed
#nlargest lists the top 5 journals
journal=welcome.groupby(['Journal title'])['Article title'].count().nlargest(5)
journal
# Out:
# Journal title
# PLoS One                                           92
# PLoS ONE                                           62
# Journal of Biological Chemistry                    48
# Nucleic Acids Research                             21
# Proceedings of the National Academy of Sciences    19
# Name: Article title, dtype: int64

# %%
#Calculate the mean, median, and standard deviation of the open-access cost per article for each journal 
# Need to change cost without the Euro sign 
# Create a series
strcost = pd.Series(welcome.iloc[:, 4])
objcost = strcost.str.split('£', expand=True)
cost = objcost[1]
cost=cost.astype(float)

# %%
type(cost)
# Out:
# pandas.core.series.Series

# %%
welcome['COST (£) charged to Wellcome (inc VAT when charged)']=cost

# %%
title=welcome.groupby(['Journal title'])

# %%
title.mean()
# Out:
#                                                     COST (£) charged to Wellcome (inc VAT when charged)
# Journal title
# ACS Chemical Biology                                                                      1418.186000
# ACS Chemical Neuroscience                                                                 1186.800000
# ACS NANO                                                                                   642.890000
# ACS Nano                                                                                   693.390000
# ACTA F                                                                                     754.900000
# AGE                                                                                       2002.000000
# AIDS                                                                                      2059.306667
# AIDS Behav                                                                                1834.770000
# ...

# %%
title.median()
# Out:
#                                                     COST (£) charged to Wellcome (inc VAT when charged)
# Journal title
# ACS Chemical Biology                                                                         1294.590
# ACS Chemical Neuroscience                                                                    1186.800
# ACS NANO                                                                                      642.890
# ACS Nano                                                                                      693.390
# ACTA F                                                                                        754.900
# AGE                                                                                          2002.000
# AIDS                                                                                         1968.630
# AIDS Behav                                                                                   1834.770
# ...

# %%
title.std()
# Out:
#                                                     COST (£) charged to Wellcome (inc VAT when charged)
# Journal title
# ACS Chemical Biology                                                                       507.309560
# ACS Chemical Neuroscience                                                                         NaN
# ACS NANO                                                                                          NaN
# ACS Nano                                                                                          NaN
# ACTA F                                                                                            NaN
# AGE                                                                                               NaN
# AIDS                                                                                       281.067979
# AIDS Behav                                                                                        NaN
# ...

# %%
welcome['Journal title'].str.contains('Bio')
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8        True
# 9        True
# 10      False
# 11      False
# 12      False
# 13       True
# 14      False
# 15      False
# 16       True
# 17      False
# 18      False
# 19       True
# 20       True
# 21       True
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28       True
# 29      False
#         ...
# 2097    False
# 2098    False
# 2099    False
# 2100    False
# 2101    False
# 2102    False
# 2103    False
# 2104    False
# 2105    False
# 2106    False
# 2107    False
# 2108    False
# 2109    False
# 2110    False
# 2111    False
# 2112    False
# 2113    False
# 2114    False
# 2115    False
# 2116    False
# 2117    False
# 2118    False
# 2119    False
# 2120    False
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# 2126    False
# ...
